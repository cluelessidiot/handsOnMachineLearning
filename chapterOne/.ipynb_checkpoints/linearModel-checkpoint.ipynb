# %%
import matplotlib
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import sklearn
# Load the data
oecd_bli = pd.read_csv("oecd_bli_2015.csv", thousands=',')
gdp_per_capita = pd.read_csv("gdp_per_capita.csv",thousands=',',delimiter='\t',
                             encoding='latin1', na_values="n/a")
# Out:
#      LOCATION          Country INDICATOR  \
# 0         AUS        Australia   HO_BASE
# 1         AUT          Austria   HO_BASE
# 2         BEL          Belgium   HO_BASE
# 3         CAN           Canada   HO_BASE
# 4         CZE   Czech Republic   HO_BASE
# 5         DNK          Denmark   HO_BASE
# 6         FIN          Finland   HO_BASE
# 7         FRA           France   HO_BASE
# 8         DEU          Germany   HO_BASE
# 9         GRC           Greece   HO_BASE
# 10        HUN          Hungary   HO_BASE
# 11        ISL          Iceland   HO_BASE
# 12        IRL          Ireland   HO_BASE
# 13        ITA            Italy   HO_BASE
# 14        JPN            Japan   HO_BASE
# 15        KOR            Korea   HO_BASE
# 16        LUX       Luxembourg   HO_BASE
# 17        MEX           Mexico   HO_BASE
# 18        NLD      Netherlands   HO_BASE
# 19        NZL      New Zealand   HO_BASE
# 20        NOR           Norway   HO_BASE
# 21        POL           Poland   HO_BASE
# 22        PRT         Portugal   HO_BASE
# 23        SVK  Slovak Republic   HO_BASE
# 24        ESP            Spain   HO_BASE
# 25        SWE           Sweden   HO_BASE
# 26        CHE      Switzerland   HO_BASE
# 27        TUR           Turkey   HO_BASE
# 28        GBR   United Kingdom   HO_BASE
# 29        USA    United States   HO_BASE
# ...       ...              ...       ...
# 3262      FRA           France   WL_TNOW
# 3263      DEU          Germany   WL_TNOW
# 3264      GRC           Greece   WL_TNOW
# 3265      HUN          Hungary   WL_TNOW
# 3266      ISL          Iceland   WL_TNOW
# 3267      IRL          Ireland   WL_TNOW
# 3268      ITA            Italy   WL_TNOW
# 3269      JPN            Japan   WL_TNOW
# 3270      KOR            Korea   WL_TNOW
# 3271      LUX       Luxembourg   WL_TNOW
# 3272      MEX           Mexico   WL_TNOW
# 3273      NLD      Netherlands   WL_TNOW
# 3274      NZL      New Zealand   WL_TNOW
# 3275      NOR           Norway   WL_TNOW
# 3276      POL           Poland   WL_TNOW
# 3277      PRT         Portugal   WL_TNOW
# 3278      SVK  Slovak Republic   WL_TNOW
# 3279      ESP            Spain   WL_TNOW
# 3280      SWE           Sweden   WL_TNOW
# 3281      CHE      Switzerland   WL_TNOW
# 3282      TUR           Turkey   WL_TNOW
# 3283      GBR   United Kingdom   WL_TNOW
# 3284      USA    United States   WL_TNOW
# 3285      BRA           Brazil   WL_TNOW
# 3286      CHL            Chile   WL_TNOW
# 3287      EST          Estonia   WL_TNOW
# 3288      ISR           Israel   WL_TNOW
# 3289      RUS           Russia   WL_TNOW
# 3290      SVN         Slovenia   WL_TNOW
# 3291     OECD     OECD - Total   WL_TNOW
#
#                                       Indicator MEASURE Measure INEQUALITY  \
# 0            Dwellings without basic facilities       L   Value        TOT
# 1            Dwellings without basic facilities       L   Value        TOT
# 2            Dwellings without basic facilities       L   Value        TOT
# 3            Dwellings without basic facilities       L   Value        TOT
# 4            Dwellings without basic facilities       L   Value        TOT
# 5            Dwellings without basic facilities       L   Value        TOT
# 6            Dwellings without basic facilities       L   Value        TOT
# 7            Dwellings without basic facilities       L   Value        TOT
# 8            Dwellings without basic facilities       L   Value        TOT
# 9            Dwellings without basic facilities       L   Value        TOT
# 10           Dwellings without basic facilities       L   Value        TOT
# 11           Dwellings without basic facilities       L   Value        TOT
# 12           Dwellings without basic facilities       L   Value        TOT
# 13           Dwellings without basic facilities       L   Value        TOT
# 14           Dwellings without basic facilities       L   Value        TOT
# 15           Dwellings without basic facilities       L   Value        TOT
# 16           Dwellings without basic facilities       L   Value        TOT
# 17           Dwellings without basic facilities       L   Value        TOT
# 18           Dwellings without basic facilities       L   Value        TOT
# 19           Dwellings without basic facilities       L   Value        TOT
# 20           Dwellings without basic facilities       L   Value        TOT
# 21           Dwellings without basic facilities       L   Value        TOT
# 22           Dwellings without basic facilities       L   Value        TOT
# 23           Dwellings without basic facilities       L   Value        TOT
# 24           Dwellings without basic facilities       L   Value        TOT
# 25           Dwellings without basic facilities       L   Value        TOT
# 26           Dwellings without basic facilities       L   Value        TOT
# 27           Dwellings without basic facilities       L   Value        TOT
# 28           Dwellings without basic facilities       L   Value        TOT
# 29           Dwellings without basic facilities       L   Value        TOT
# ...                                         ...     ...     ...        ...
# 3262  Time devoted to leisure and personal care       L   Value        WMN
# 3263  Time devoted to leisure and personal care       L   Value        WMN
# 3264  Time devoted to leisure and personal care       L   Value        WMN
# 3265  Time devoted to leisure and personal care       L   Value        WMN
# 3266  Time devoted to leisure and personal care       L   Value        WMN
# 3267  Time devoted to leisure and personal care       L   Value        WMN
# 3268  Time devoted to leisure and personal care       L   Value        WMN
# 3269  Time devoted to leisure and personal care       L   Value        WMN
# 3270  Time devoted to leisure and personal care       L   Value        WMN
# 3271  Time devoted to leisure and personal care       L   Value        WMN
# 3272  Time devoted to leisure and personal care       L   Value        WMN
# 3273  Time devoted to leisure and personal care       L   Value        WMN
# 3274  Time devoted to leisure and personal care       L   Value        WMN
# 3275  Time devoted to leisure and personal care       L   Value        WMN
# 3276  Time devoted to leisure and personal care       L   Value        WMN
# 3277  Time devoted to leisure and personal care       L   Value        WMN
# 3278  Time devoted to leisure and personal care       L   Value        WMN
# 3279  Time devoted to leisure and personal care       L   Value        WMN
# 3280  Time devoted to leisure and personal care       L   Value        WMN
# 3281  Time devoted to leisure and personal care       L   Value        WMN
# 3282  Time devoted to leisure and personal care       L   Value        WMN
# 3283  Time devoted to leisure and personal care       L   Value        WMN
# 3284  Time devoted to leisure and personal care       L   Value        WMN
# 3285  Time devoted to leisure and personal care       L   Value        WMN
# 3286  Time devoted to leisure and personal care       L   Value        WMN
# 3287  Time devoted to leisure and personal care       L   Value        WMN
# 3288  Time devoted to leisure and personal care       L   Value        WMN
# 3289  Time devoted to leisure and personal care       L   Value        WMN
# 3290  Time devoted to leisure and personal care       L   Value        WMN
# 3291  Time devoted to leisure and personal care       L   Value        WMN
#
#      Inequality Unit Code        Unit  PowerCode Code PowerCode  \
# 0         Total        PC  Percentage               0     units
# 1         Total        PC  Percentage               0     units
# 2         Total        PC  Percentage               0     units
# 3         Total        PC  Percentage               0     units
# 4         Total        PC  Percentage               0     units
# 5         Total        PC  Percentage               0     units
# 6         Total        PC  Percentage               0     units
# 7         Total        PC  Percentage               0     units
# 8         Total        PC  Percentage               0     units
# 9         Total        PC  Percentage               0     units
# 10        Total        PC  Percentage               0     units
# 11        Total        PC  Percentage               0     units
# 12        Total        PC  Percentage               0     units
# 13        Total        PC  Percentage               0     units
# 14        Total        PC  Percentage               0     units
# 15        Total        PC  Percentage               0     units
# 16        Total        PC  Percentage               0     units
# 17        Total        PC  Percentage               0     units
# 18        Total        PC  Percentage               0     units
# 19        Total        PC  Percentage               0     units
# 20        Total        PC  Percentage               0     units
# 21        Total        PC  Percentage               0     units
# 22        Total        PC  Percentage               0     units
# 23        Total        PC  Percentage               0     units
# 24        Total        PC  Percentage               0     units
# 25        Total        PC  Percentage               0     units
# 26        Total        PC  Percentage               0     units
# 27        Total        PC  Percentage               0     units
# 28        Total        PC  Percentage               0     units
# 29        Total        PC  Percentage               0     units
# ...         ...       ...         ...             ...       ...
# 3262      Women      HOUR       Hours               0     units
# 3263      Women      HOUR       Hours               0     units
# 3264      Women      HOUR       Hours               0     units
# 3265      Women      HOUR       Hours               0     units
# 3266      Women      HOUR       Hours               0     units
# 3267      Women      HOUR       Hours               0     units
# 3268      Women      HOUR       Hours               0     units
# 3269      Women      HOUR       Hours               0     units
# 3270      Women      HOUR       Hours               0     units
# 3271      Women      HOUR       Hours               0     units
# 3272      Women      HOUR       Hours               0     units
# 3273      Women      HOUR       Hours               0     units
# 3274      Women      HOUR       Hours               0     units
# 3275      Women      HOUR       Hours               0     units
# 3276      Women      HOUR       Hours               0     units
# 3277      Women      HOUR       Hours               0     units
# 3278      Women      HOUR       Hours               0     units
# 3279      Women      HOUR       Hours               0     units
# 3280      Women      HOUR       Hours               0     units
# 3281      Women      HOUR       Hours               0     units
# 3282      Women      HOUR       Hours               0     units
# 3283      Women      HOUR       Hours               0     units
# 3284      Women      HOUR       Hours               0     units
# 3285      Women      HOUR       Hours               0     units
# 3286      Women      HOUR       Hours               0     units
# 3287      Women      HOUR       Hours               0     units
# 3288      Women      HOUR       Hours               0     units
# 3289      Women      HOUR       Hours               0     units
# 3290      Women      HOUR       Hours               0     units
# 3291      Women      HOUR       Hours               0     units
#
#       Reference Period Code  Reference Period  Value Flag Codes  \
# 0                       NaN               NaN   1.10          E
# 1                       NaN               NaN   1.00        NaN
# 2                       NaN               NaN   2.00        NaN
# 3                       NaN               NaN   0.20        NaN
# 4                       NaN               NaN   0.90        NaN
# 5                       NaN               NaN   0.90        NaN
# 6                       NaN               NaN   0.60        NaN
# 7                       NaN               NaN   0.50        NaN
# 8                       NaN               NaN   0.10        NaN
# 9                       NaN               NaN   0.70        NaN
# 10                      NaN               NaN   4.80        NaN
# 11                      NaN               NaN   0.40        NaN
# 12                      NaN               NaN   0.20        NaN
# 13                      NaN               NaN   1.10        NaN
# 14                      NaN               NaN   6.40        NaN
# 15                      NaN               NaN   4.20        NaN
# 16                      NaN               NaN   0.10        NaN
# 17                      NaN               NaN   4.20        NaN
# 18                      NaN               NaN   0.00        NaN
# 19                      NaN               NaN   0.20          E
# 20                      NaN               NaN   0.30        NaN
# 21                      NaN               NaN   3.20        NaN
# 22                      NaN               NaN   0.90        NaN
# 23                      NaN               NaN   0.60        NaN
# 24                      NaN               NaN   0.10        NaN
# 25                      NaN               NaN   0.00        NaN
# 26                      NaN               NaN   0.00        NaN
# 27                      NaN               NaN  12.70        NaN
# 28                      NaN               NaN   0.20        NaN
# 29                      NaN               NaN   0.10        NaN
# ...                     ...               ...    ...        ...
# 3262                    NaN               NaN  14.90        NaN
# 3263                    NaN               NaN  15.31        NaN
# 3264                    NaN               NaN  14.69          E
# 3265                    NaN               NaN  14.82          E
# 3266                    NaN               NaN  14.37          E
# 3267                    NaN               NaN  14.97          E
# 3268                    NaN               NaN  14.32        NaN
# 3269                    NaN               NaN  14.88        NaN
# 3270                    NaN               NaN  14.07        NaN
# 3271                    NaN               NaN  14.90          E
# 3272                    NaN               NaN  13.63          E
# 3273                    NaN               NaN  15.23          E
# 3274                    NaN               NaN  14.93        NaN
# 3275                    NaN               NaN  15.67        NaN
# 3276                    NaN               NaN  13.83        NaN
# 3277                    NaN               NaN  14.72          E
# 3278                    NaN               NaN  14.76          E
# 3279                    NaN               NaN  15.52        NaN
# 3280                    NaN               NaN  15.30        NaN
# 3281                    NaN               NaN  14.76          E
# 3282                    NaN               NaN  13.13          E
# 3283                    NaN               NaN  14.60        NaN
# 3284                    NaN               NaN  14.12        NaN
# 3285                    NaN               NaN  14.75          E
# 3286                    NaN               NaN  14.16          E
# 3287                    NaN               NaN  14.43        NaN
# 3288                    NaN               NaN  14.24          E
# 3289                    NaN               NaN  14.75          E
# 3290                    NaN               NaN  14.12        NaN
# 3291                    NaN               NaN  14.74        NaN
#
#                 Flags
# 0     Estimated value
# 1                 NaN
# 2                 NaN
# 3                 NaN
# 4                 NaN
# 5                 NaN
# 6                 NaN
# 7                 NaN
# 8                 NaN
# 9                 NaN
# 10                NaN
# 11                NaN
# 12                NaN
# 13                NaN
# 14                NaN
# 15                NaN
# 16                NaN
# 17                NaN
# 18                NaN
# 19    Estimated value
# 20                NaN
# 21                NaN
# 22                NaN
# 23                NaN
# 24                NaN
# 25                NaN
# 26                NaN
# 27                NaN
# 28                NaN
# 29                NaN
# ...               ...
# 3262              NaN
# 3263              NaN
# 3264  Estimated value
# 3265  Estimated value
# 3266  Estimated value
# 3267  Estimated value
# 3268              NaN
# 3269              NaN
# 3270              NaN
# 3271  Estimated value
# 3272  Estimated value
# 3273  Estimated value
# 3274              NaN
# 3275              NaN
# 3276              NaN
# 3277  Estimated value
# 3278  Estimated value
# 3279              NaN
# 3280              NaN
# 3281  Estimated value
# 3282  Estimated value
# 3283              NaN
# 3284              NaN
# 3285  Estimated value
# 3286  Estimated value
# 3287              NaN
# 3288  Estimated value
# 3289  Estimated value
# 3290              NaN
# 3291              NaN
#
# [3292 rows x 17 columns]

# %%
def prepare_country_stats(oecd_bli, gdp_per_capita):
    print (oecd_bli[oecd_bli["LOCATION"]=="AUT"])
    oecd_bli = oecd_bli[oecd_bli["INEQUALITY"]=="TOT"]
    print("----------------------------------")
  #  print (oecd_bli)
    oecd_bli = oecd_bli.pivot(index="Country", columns="Indicator", values="Value")
    gdp_per_capita.rename(columns={"2015": "GDP per capita"}, inplace=True)
    gdp_per_capita.set_index("Country", inplace=True)
    full_country_stats = pd.merge(left=oecd_bli, right=gdp_per_capita,
                                  left_index=True, right_index=True)
    full_country_stats.sort_values(by="GDP per capita", inplace=True)
    print (full_country_stats)
   # print (full_country_stats)
    remove_indices = [0, 1, 6, 8, 33, 34, 35]
    keep_indices = list(set(range(36)) - set(remove_indices))
    return full_country_stats[["GDP per capita", 'Life satisfaction']].iloc[keep_indices]

# %%
# Prepare the data
country_stats = prepare_country_stats(oecd_bli, gdp_per_capita)
X = np.c_[country_stats["GDP per capita"]]
y = np.c_[country_stats["Life satisfaction"]]
# Out:
#      LOCATION  Country INDICATOR                                  Indicator  \
# 1         AUT  Austria   HO_BASE         Dwellings without basic facilities
# 38        AUT  Austria   HO_BASE         Dwellings without basic facilities
# 74        AUT  Austria   HO_BASE         Dwellings without basic facilities
# 110       AUT  Austria   HO_HISH                        Housing expenditure
# 147       AUT  Austria   HO_HISH                        Housing expenditure
# 183       AUT  Austria   HO_HISH                        Housing expenditure
# 219       AUT  Austria   HO_NUMR                           Rooms per person
# 256       AUT  Austria   HO_NUMR                           Rooms per person
# 292       AUT  Austria   HO_NUMR                           Rooms per person
# 328       AUT  Austria   IW_HADI   Household net adjusted disposable income
# 365       AUT  Austria   IW_HADI   Household net adjusted disposable income
# 401       AUT  Austria   IW_HADI   Household net adjusted disposable income
# 437       AUT  Austria   IW_HADI   Household net adjusted disposable income
# 474       AUT  Austria   IW_HADI   Household net adjusted disposable income
# 511       AUT  Austria   IW_HNFW             Household net financial wealth
# 548       AUT  Austria   IW_HNFW             Household net financial wealth
# 584       AUT  Austria   IW_HNFW             Household net financial wealth
# 620       AUT  Austria   JE_EMPL                            Employment rate
# 657       AUT  Austria   JE_EMPL                            Employment rate
# 694       AUT  Austria   JE_EMPL                            Employment rate
# 731       AUT  Austria   JE_EMPL                            Employment rate
# 768       AUT  Austria   JE_EMPL                            Employment rate
# 805       AUT  Austria     JE_JT                               Job security
# 842       AUT  Austria     JE_JT                               Job security
# 879       AUT  Austria     JE_JT                               Job security
# 916       AUT  Austria   JE_LTUR                Long-term unemployment rate
# 953       AUT  Austria   JE_LTUR                Long-term unemployment rate
# 990       AUT  Austria   JE_LTUR                Long-term unemployment rate
# 1027      AUT  Austria   JE_LTUR                Long-term unemployment rate
# 1064      AUT  Austria   JE_LTUR                Long-term unemployment rate
# ...       ...      ...       ...                                        ...
# 2189      AUT  Austria   CG_VOTO                              Voter turnout
# 2226      AUT  Austria   CG_VOTO                              Voter turnout
# 2263      AUT  Austria   CG_VOTO                              Voter turnout
# 2300      AUT  Austria   CG_VOTO                              Voter turnout
# 2337      AUT  Austria   CG_VOTO                              Voter turnout
# 2374      AUT  Austria    HS_LEB                            Life expectancy
# 2411      AUT  Austria    HS_LEB                            Life expectancy
# 2448      AUT  Austria    HS_LEB                            Life expectancy
# 2485      AUT  Austria   HS_SFRH                       Self-reported health
# 2522      AUT  Austria   HS_SFRH                       Self-reported health
# 2559      AUT  Austria   HS_SFRH                       Self-reported health
# 2596      AUT  Austria   HS_SFRH                       Self-reported health
# 2633      AUT  Austria   HS_SFRH                       Self-reported health
# 2670      AUT  Austria   SW_LIFS                          Life satisfaction
# 2707      AUT  Austria   SW_LIFS                          Life satisfaction
# 2744      AUT  Austria   SW_LIFS                          Life satisfaction
# 2781      AUT  Austria   SW_LIFS                          Life satisfaction
# 2817      AUT  Austria   SW_LIFS                          Life satisfaction
# 2849      AUT  Austria   PS_SFRV                               Assault rate
# 2886      AUT  Austria   PS_SFRV                               Assault rate
# 2923      AUT  Austria   PS_SFRV                               Assault rate
# 2960      AUT  Austria   PS_REPH                              Homicide rate
# 2997      AUT  Austria   PS_REPH                              Homicide rate
# 3034      AUT  Austria   PS_REPH                              Homicide rate
# 3071      AUT  Austria   WL_EWLH          Employees working very long hours
# 3108      AUT  Austria   WL_EWLH          Employees working very long hours
# 3145      AUT  Austria   WL_EWLH          Employees working very long hours
# 3182      AUT  Austria   WL_TNOW  Time devoted to leisure and personal care
# 3219      AUT  Austria   WL_TNOW  Time devoted to leisure and personal care
# 3256      AUT  Austria   WL_TNOW  Time devoted to leisure and personal care
#
#      MEASURE Measure INEQUALITY Inequality Unit Code           Unit  \
# 1          L   Value        TOT      Total        PC     Percentage
# 38         L   Value         MN        Men        PC     Percentage
# 74         L   Value        WMN      Women        PC     Percentage
# 110        L   Value        TOT      Total        PC     Percentage
# 147        L   Value         MN        Men        PC     Percentage
# 183        L   Value        WMN      Women        PC     Percentage
# 219        L   Value        TOT      Total     RATIO          Ratio
# 256        L   Value         MN        Men     RATIO          Ratio
# 292        L   Value        WMN      Women     RATIO          Ratio
# 328        L   Value        TOT      Total       USD      US Dollar
# 365        L   Value         MN        Men       USD      US Dollar
# 401        L   Value        WMN      Women       USD      US Dollar
# 437        L   Value        HGH       High       USD      US Dollar
# 474        L   Value         LW        Low       USD      US Dollar
# 511        L   Value        TOT      Total       USD      US Dollar
# 548        L   Value         MN        Men       USD      US Dollar
# 584        L   Value        WMN      Women       USD      US Dollar
# 620        L   Value        TOT      Total        PC     Percentage
# 657        L   Value         MN        Men        PC     Percentage
# 694        L   Value        WMN      Women        PC     Percentage
# 731        L   Value        HGH       High        PC     Percentage
# 768        L   Value         LW        Low        PC     Percentage
# 805        L   Value        TOT      Total        PC     Percentage
# 842        L   Value         MN        Men        PC     Percentage
# 879        L   Value        WMN      Women        PC     Percentage
# 916        L   Value        TOT      Total        PC     Percentage
# 953        L   Value         MN        Men        PC     Percentage
# 990        L   Value        WMN      Women        PC     Percentage
# 1027       L   Value        HGH       High        PC     Percentage
# 1064       L   Value         LW        Low        PC     Percentage
# ...      ...     ...        ...        ...       ...            ...
# 2189       L   Value        TOT      Total        PC     Percentage
# 2226       L   Value         MN        Men        PC     Percentage
# 2263       L   Value        WMN      Women        PC     Percentage
# 2300       L   Value        HGH       High        PC     Percentage
# 2337       L   Value         LW        Low        PC     Percentage
# 2374       L   Value        TOT      Total        YR          Years
# 2411       L   Value         MN        Men        YR          Years
# 2448       L   Value        WMN      Women        YR          Years
# 2485       L   Value        TOT      Total        PC     Percentage
# 2522       L   Value         MN        Men        PC     Percentage
# 2559       L   Value        WMN      Women        PC     Percentage
# 2596       L   Value        HGH       High        PC     Percentage
# 2633       L   Value         LW        Low        PC     Percentage
# 2670       L   Value        TOT      Total   AVSCORE  Average score
# 2707       L   Value         MN        Men   AVSCORE  Average score
# 2744       L   Value        WMN      Women   AVSCORE  Average score
# 2781       L   Value        HGH       High   AVSCORE  Average score
# 2817       L   Value         LW        Low   AVSCORE  Average score
# 2849       L   Value        TOT      Total        PC     Percentage
# 2886       L   Value         MN        Men        PC     Percentage
# 2923       L   Value        WMN      Women        PC     Percentage
# 2960       L   Value        TOT      Total     RATIO          Ratio
# 2997       L   Value         MN        Men     RATIO          Ratio
# 3034       L   Value        WMN      Women     RATIO          Ratio
# 3071       L   Value        TOT      Total        PC     Percentage
# 3108       L   Value         MN        Men        PC     Percentage
# 3145       L   Value        WMN      Women        PC     Percentage
# 3182       L   Value        TOT      Total      HOUR          Hours
# 3219       L   Value         MN        Men      HOUR          Hours
# 3256       L   Value        WMN      Women      HOUR          Hours
#
#       PowerCode Code PowerCode  Reference Period Code  Reference Period  \
# 1                  0     units                    NaN               NaN
# 38                 0     units                    NaN               NaN
# 74                 0     units                    NaN               NaN
# 110                0     units                    NaN               NaN
# 147                0     units                    NaN               NaN
# 183                0     units                    NaN               NaN
# 219                0     units                    NaN               NaN
# 256                0     units                    NaN               NaN
# 292                0     units                    NaN               NaN
# 328                0     units                    NaN               NaN
# 365                0     units                    NaN               NaN
# 401                0     units                    NaN               NaN
# 437                0     units                    NaN               NaN
# 474                0     units                    NaN               NaN
# 511                0     units                    NaN               NaN
# 548                0     units                    NaN               NaN
# 584                0     units                    NaN               NaN
# 620                0     units                    NaN               NaN
# 657                0     units                    NaN               NaN
# 694                0     units                    NaN               NaN
# 731                0     units                    NaN               NaN
# 768                0     units                    NaN               NaN
# 805                0     units                    NaN               NaN
# 842                0     units                    NaN               NaN
# 879                0     units                    NaN               NaN
# 916                0     units                    NaN               NaN
# 953                0     units                    NaN               NaN
# 990                0     units                    NaN               NaN
# 1027               0     units                    NaN               NaN
# 1064               0     units                    NaN               NaN
# ...              ...       ...                    ...               ...
# 2189               0     units                    NaN               NaN
# 2226               0     units                    NaN               NaN
# 2263               0     units                    NaN               NaN
# 2300               0     units                    NaN               NaN
# 2337               0     units                    NaN               NaN
# 2374               0     units                    NaN               NaN
# 2411               0     units                    NaN               NaN
# 2448               0     units                    NaN               NaN
# 2485               0     units                    NaN               NaN
# 2522               0     units                    NaN               NaN
# 2559               0     units                    NaN               NaN
# 2596               0     units                    NaN               NaN
# 2633               0     units                    NaN               NaN
# 2670               0     units                    NaN               NaN
# 2707               0     units                    NaN               NaN
# 2744               0     units                    NaN               NaN
# 2781               0     units                    NaN               NaN
# 2817               0     units                    NaN               NaN
# 2849               0     units                    NaN               NaN
# 2886               0     units                    NaN               NaN
# 2923               0     units                    NaN               NaN
# 2960               0     units                    NaN               NaN
# 2997               0     units                    NaN               NaN
# 3034               0     units                    NaN               NaN
# 3071               0     units                    NaN               NaN
# 3108               0     units                    NaN               NaN
# 3145               0     units                    NaN               NaN
# 3182               0     units                    NaN               NaN
# 3219               0     units                    NaN               NaN
# 3256               0     units                    NaN               NaN
#
#              Value Flag Codes            Flags
# 1         1.000000        NaN              NaN
# 38        1.000000          E  Estimated value
# 74        1.000000          E  Estimated value
# 110      21.000000        NaN              NaN
# 147      21.000000          E  Estimated value
# 183      21.000000          E  Estimated value
# 219       1.600000        NaN              NaN
# 256       1.600000          E  Estimated value
# 292       1.600000          E  Estimated value
# 328   31173.000000        NaN              NaN
# 365   31173.000000          E  Estimated value
# 401   31173.000000          E  Estimated value
# 437   57234.000000          E  Estimated value
# 474   13141.000000          E  Estimated value
# 511   49887.000000        NaN              NaN
# 548   49887.000000          E  Estimated value
# 584   49887.000000          E  Estimated value
# 620      72.000000        NaN              NaN
# 657      77.000000        NaN              NaN
# 694      68.000000        NaN              NaN
# 731      86.000000          E  Estimated value
# 768      48.000000          E  Estimated value
# 805       3.900000        NaN              NaN
# 842       3.900000        NaN              NaN
# 879       4.000000        NaN              NaN
# 916       1.190000        NaN              NaN
# 953       1.240000        NaN              NaN
# 990       1.134178        NaN              NaN
# 1027      0.730000          E  Estimated value
# 1064      2.390000          E  Estimated value
# ...            ...        ...              ...
# 2189     75.000000        NaN              NaN
# 2226     77.000000          E  Estimated value
# 2263     73.000000          E  Estimated value
# 2300     82.000000          E  Estimated value
# 2337     72.000000          E  Estimated value
# 2374     81.000000        NaN              NaN
# 2411     78.400000        NaN              NaN
# 2448     83.600000        NaN              NaN
# 2485     69.000000        NaN              NaN
# 2522     71.000000        NaN              NaN
# 2559     67.000000        NaN              NaN
# 2596     80.000000        NaN              NaN
# 2633     60.000000        NaN              NaN
# 2670      6.900000        NaN              NaN
# 2707      6.900000        NaN              NaN
# 2744      7.000000        NaN              NaN
# 2781      7.600000        NaN              NaN
# 2817      6.900000        NaN              NaN
# 2849      3.400000        NaN              NaN
# 2886      4.600000        NaN              NaN
# 2923      2.400000        NaN              NaN
# 2960      0.400000        NaN              NaN
# 2997      0.400000        NaN              NaN
# 3034      0.400000        NaN              NaN
# 3071      7.610000        NaN              NaN
# 3108     11.780000        NaN              NaN
# 3145      3.140000        NaN              NaN
# 3182     14.460000        NaN              NaN
# 3219     14.600000        NaN              NaN
# 3256     14.150000        NaN              NaN
#
# [89 rows x 17 columns]
# ----------------------------------
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# //anaconda3/lib/python3.7/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2656             try:
# -> 2657                 return self._engine.get_loc(key)
#    2658             except KeyError:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Country'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-33-523124ca47df> in <module>
#       1 # Prepare the data
# ----> 2 country_stats = prepare_country_stats(oecd_bli, gdp_per_capita)
#       3 X = np.c_[country_stats["GDP per capita"]]
#       4 y = np.c_[country_stats["Life satisfaction"]]
#
# <ipython-input-32-f25acc06e68c> in prepare_country_stats(oecd_bli, gdp_per_capita)
#       6     oecd_bli = oecd_bli.pivot(index="Country", columns="Indicator", values="Value")
#       7     gdp_per_capita.rename(columns={"2015": "GDP per capita"}, inplace=True)
# ----> 8     gdp_per_capita.set_index("Country", inplace=True)
#       9     full_country_stats = pd.merge(left=oecd_bli, right=gdp_per_capita,
#      10                                   left_index=True, right_index=True)
#
# //anaconda3/lib/python3.7/site-packages/pandas/core/frame.py in set_index(self, keys, drop, append, inplace, verify_integrity)
#    4176                 names.append(None)
#    4177             else:
# -> 4178                 level = frame[col]._values
#    4179                 names.append(col)
#    4180                 if drop:
#
# //anaconda3/lib/python3.7/site-packages/pandas/core/frame.py in __getitem__(self, key)
#    2925             if self.columns.nlevels > 1:
#    2926                 return self._getitem_multilevel(key)
# -> 2927             indexer = self.columns.get_loc(key)
#    2928             if is_integer(indexer):
#    2929                 indexer = [indexer]
#
# //anaconda3/lib/python3.7/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2657                 return self._engine.get_loc(key)
#    2658             except KeyError:
# -> 2659                 return self._engine.get_loc(self._maybe_cast_indexer(key))
#    2660         indexer = self.get_indexer([key], method=method, tolerance=tolerance)
#    2661         if indexer.ndim > 1 or indexer.size > 1:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Country'

# %%
# Visualize the data
country_stats.plot(kind='scatter', x="GDP per capita", y='Life satisfaction')
plt.show()

# %%
# Select a linear model
lin_reg_model = sklearn.linear_model.LinearRegression() # Train the model
lin_reg_model.fit(X, y)
# Make a prediction for Cyprus
X_new = [[22587]] # Cyprus' GDP per capita print(lin_reg_model.predict(X_new)) # outputs [[ 5.96242338]]
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-5-f517a9f899ca> in <module>
#       1 # Select a linear model
# ----> 2 lin_reg_model = sklearn.linear_model.LinearRegression() # Train the model
#       3 lin_reg_model.fit(X, y)
#       4 # Make a prediction for Cyprus
#       5 X_new = [[22587]] # Cyprus' GDP per capita print(lin_reg_model.predict(X_new)) # outputs [[ 5.96242338]]
#
# AttributeError: module 'sklearn' has no attribute 'linear_model'
